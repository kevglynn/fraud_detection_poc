# %%
import graphlab as gl

# %%
data = gl.SFrame.read_csv("Integral_data_set.tsv", sep="\t", header=False)
# Out:
# Unable to parse line "2014-08-25 00:00:00	325.441.386.395	Unknown	Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36	http://www.mangareader.net"
# Unable to parse line "2014-08-25 06:16:26	325.489.375.541	Safari/Webkit	Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2	http://www.suggest.com	0.0	11	(0,0,1324,850)"
# Unable to parse line "2014-08-25 20:37:36	324.489.478.360	Firefox	Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0	http://wowway.net	0.0	13	(-4,-4,1032,746)"
# Unable to parse line "2014-08-25 00:00:00	325.441.386.395	Unknown	Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36	http://www.mangareader.net"
# Unable to parse line "2014-08-25 12:49:10	411.517.507.552	Unknown	Mozilla/5.0 (Windows NT 6.1; rv:31.0) Gecko/20100101 Firefox/31.0	http://www.huffingtonpost.com"
# ...

# %%
data.show()
# Out:
# Canvas is updated and available in a tab in the default browser.

# %%
header_list = ["X"+str(i) for i in range(1,10)]

# %%
header_list
# Out:
# ['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9']

# %%
header_names = ["Timestamp","IP address","Detected browser type","User agent string","Host (URL)", 
                "Whether the impression was in view (1.0 = yes, 0.0 = no)", 
                "Number of plugins installed","Browser window position and size (x, y, width, height)",
                "Network latency"]

# %%
header_dict = dict(zip(header_list,header_names))

# %%
data.rename(header_dict)
# Out:
# Columns:
# 	Timestamp	str
# 	IP address	str
# 	Detected browser type	str
# 	User agent string	str
# 	Host (URL)	str
# 	Whether the impression was in view (1.0 = yes, 0.0 = no)	float
# 	Number of plugins installed	int
# 	Browser window position and size (x, y, width, height)	str
# 	Network latency	int
#
# Rows: 200283
#
# Data:
# +---------------------+-----------------+-----------------------+
# |      Timestamp      |    IP address   | Detected browser type |
# +---------------------+-----------------+-----------------------+
# | 2014-08-25 00:00:00 | 393.414.443.469 |     Safari/Webkit     |
# | 2014-08-25 00:00:00 | 393.414.443.469 |     Safari/Webkit     |
# | 2014-08-25 00:00:00 | 326.432.563.561 |         Chrome        |
# | 2014-08-25 00:00:03 | 386.335.512.400 |     Safari/Webkit     |
# | 2014-08-25 00:00:03 | 488.432.432.344 |         Chrome        |
# | 2014-08-25 00:00:03 | 412.428.488.484 |         Chrome        |
# ...

# %%
# Transform string date into datetime type.
# This will help us further along to compare dates.
import pandas as pd
data['Timestamp'] = data['Timestamp'].apply(lambda x: pd.to_datetime(x))

# Split date into its components and set them as categorical features 
data.add_columns(data['Timestamp'].split_datetime(limit=['year','month','day'], column_name_prefix='transaction'))
data['transaction.year'] = data['transaction.year'].astype(str)
data['transaction.month'] = data['transaction.month'].astype(str)
data['transaction.day'] = data['transaction.day'].astype(str)

# %%
data.show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:63268/index.html
# Opening Canvas in default web browser.

# %%
gl.canvas.set_target("ipynb")

# %%
data.show()
